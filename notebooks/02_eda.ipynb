# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

# %%
df = pd.read_csv("../data/processed/cleaned_weather_data.csv")

# %%
df.shape
# Out:
# (311, 7)

# %%
df.describe()
# Out:
#        avg_temperature    humidity  avg_wind_speed  rain_or_not  cloud_cover  \
# count       311.000000  311.000000      311.000000   311.000000   311.000000
# mean         25.983840   55.041385        7.410985     0.636656    49.834827
# std           6.635859   18.749365        4.393116     0.481738    28.298916
# min          15.000000   30.000000        0.069480     0.000000     0.321826
# 25%          20.493383   35.686194        3.711684     0.000000    25.955498
# 50%          25.983840   55.041385        7.326421     1.000000    49.834827
# 75%          31.858688   71.978037       10.897166     1.000000    74.162107
# max          35.000000   90.000000       21.675390     1.000000    99.834751
#
#           pressure
# count   311.000000
# mean   1001.059119
# std      28.835595
# min     951.240404
# 25%     975.757545
# 50%    1001.938586
# 75%    1026.578884
# max    1049.543752

# %%
print(df["rain_or_not"].value_counts())
sns.countplot(x="rain_or_not", data=df)
# Out:
# rain_or_not
# 1    198
# 0    113
# Name: count, dtype: int64
# <Axes: xlabel='rain_or_not', ylabel='count'>

# %%
num_cols = df.select_dtypes(include="number").columns
print(num_cols)

for col in num_cols:
    if col == "rain_or_not":
        continue
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
# Out:
# Index(['avg_temperature', 'humidity', 'avg_wind_speed', 'rain_or_not',
#        'cloud_cover', 'pressure'],
#       dtype='str')

# %%
for col in num_cols:
    if col == "rain_or_not":
        continue
    plt.figure()
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")

# %%
for col in num_cols:
    if col == "rain_or_not":
        continue

    plt.figure()
    sns.boxplot(x=df["rain_or_not"], y=col , data=df)
    plt.title(f"Boxplot of {col}")

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df[num_cols].corr(), annot=True)
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')
